# %%
import pandas as pd

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\melis\anaconda3\envs\matching_ia\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\melis\anaconda3\envs\matching_ia\lib\site-packages (from openpyxl) (2.0.0)

# %%
posts_df1 = pd.read_csv('Data/combined_no_duplicates_post.csv')
posts_df2 = pd.read_excel('Data/OffreF.xlsx')

# %%
posts_df1
# Out:
#                                               Nom_poste  \
# 0                                DBA SQL/Big Data (H/F)
# 1                                    Data analyst (H/F)
# 2     Contrôle de gestion données sociales RH/Data A...
# 3                      Comptable /Data contrôleur (h/f)
# 4                     Ingénieur Data GCP Confirmé (H/F)
# ...                                                 ...
# 1530  Alternance Ingénieur Data analyst - Munster (H/F)
# 1531  Alternance Data analyst/testeur - Paris La Déf...
# 1532   Alternance Data analyst - Toussus-le-Noble (H/F)
# 1533                  Data Analyst - Biomasse - CDD H/F
# 1534                   Stream leader data ibp f/h (H/F)
#
#                                                 Contrat  \
# 0                            CDI\r\n\r\nContrat travail
# 1              Intérim - 18 Mois\r\n\r\nContrat travail
# 2                            CDI\r\n\r\nContrat travail
# 3                            CDI\r\n\r\nContrat travail
# 4                            CDI\r\n\r\nContrat travail
# ...                                                 ...
# 1530  \r\nContrat à durée déterminée - 12 Mois\r\n\r...
# 1531  \r\nContrat à durée déterminée - 12 Mois\r\n\r...
# 1532  \r\nContrat à durée déterminée - 12 Mois\r\n\r...
# 1533  \r\nContrat à durée déterminée - 12 Mois\r\n\r...
# 1534  \r\nContrat à durée indéterminée\r\n\r\nContra...
#
#                                             Description  \
# 0     Dans le cadre d'un projet d'envergure avec un ...
# 1     Manpower ARMENTIERES recherche pour son client...
# 2     LHH Recruitment Solutions, cabinet de conseil ...
# 3     LHH Recruitment Solutions, cabinet de conseil ...
# 4     Sous la responsabilité du manager Data/IA, au ...
# ...                                                 ...
# 1530  Description :\r\nL'ISCOD, expert en formation ...
# 1531  Description :\r\nL'ISCOD, spécialiste de la fo...
# 1532  Description :\r\nL'ISCOD, spécialiste de la fo...
# 1533  En tant que Data Analyst, vous serez en charge...
# 1534  Safran est un groupe international de haute te...
#
#                                                 Salaire  \
# 0     Salaire brut : Annuel de 45000.0 Euros à 65000...
# 1                                 Salaire brut : Autres
# 2     Salaire brut : Annuel de 40000.0 Euros à 45000...
# 3                   Salaire brut : Salaire selon profil
# 4     Salaire brut : Annuel de 30000.0 Euros à 40000...
# ...                                                 ...
# 1530                                                NaN
# 1531                                                NaN
# 1532                                                NaN
# 1533                                                NaN
# 1534                                                NaN
#
#                                  Experience  \
# 0                                   5 An(s)
# 1                                   2 An(s)
# 2     3 An(s) - analyse données sociales...
# 3                                   1 An(s)
# 4                                   5 An(s)
# ...                                     ...
# 1530        Expérience souhaitée de 1 An(s)
# 1531        Expérience souhaitée de 1 An(s)
# 1532        Expérience souhaitée de 1 An(s)
# 1533                       Débutant accepté
# 1534                      Expérience exigée
#
#                                Entreprise
# 0             INFORMATIS TECHNOLOGY SYSTM
# 1                         MANPOWER FRANCE
# 2                                  ADECCO
# 3                           ADECCO FRANCE
# 4     SOCIETE DE FORMATIQUE ET FINANCIERE
# ...                                   ...
# 1530                        \r\nISCOD\r\n
# 1531                        \r\nISCOD\r\n
# 1532                        \r\nISCOD\r\n
# 1533                                  NaN
# 1534                                  NaN
#
# [1535 rows x 6 columns]

# %%
posts_df2 = posts_df2.drop(columns=['Unnamed: 7', 'Unnamed: 8'])

# %%
posts_df1.describe()
# Out:
#                  Nom_poste                                            Contrat  \
# count                 1511                                               1522
# unique                1046                                                 68
# top     Data manager (H/F)  Contrat à durée indéterminée\r\n\r\nContrat tr...
# freq                    57                                                597
#
#                                               Description  \
# count                                                1525
# unique                                               1499
# top     Descriptif du poste:\r\n\r\nEn tant que Consul...
# freq                                                    4
#
#                           Salaire         Experience               Entreprise
# count                         835               1530                     1218
# unique                        433                 48                      774
# top     Salaire brut : A négocier  Expérience exigée  \r\nOrange Business\r\n
# freq                          143                408                       12

# %%
posts_df1
# Out:
#                                               Nom_poste  \
# 0                                DBA SQL/Big Data (H/F)
# 1                                    Data analyst (H/F)
# 2     Contrôle de gestion données sociales RH/Data A...
# 3                      Comptable /Data contrôleur (h/f)
# 4                     Ingénieur Data GCP Confirmé (H/F)
# ...                                                 ...
# 1530  Alternance Ingénieur Data analyst - Munster (H/F)
# 1531  Alternance Data analyst/testeur - Paris La Déf...
# 1532   Alternance Data analyst - Toussus-le-Noble (H/F)
# 1533                  Data Analyst - Biomasse - CDD H/F
# 1534                   Stream leader data ibp f/h (H/F)
#
#                                                 Contrat  \
# 0                            CDI\r\n\r\nContrat travail
# 1              Intérim - 18 Mois\r\n\r\nContrat travail
# 2                            CDI\r\n\r\nContrat travail
# 3                            CDI\r\n\r\nContrat travail
# 4                            CDI\r\n\r\nContrat travail
# ...                                                 ...
# 1530  \r\nContrat à durée déterminée - 12 Mois\r\n\r...
# 1531  \r\nContrat à durée déterminée - 12 Mois\r\n\r...
# 1532  \r\nContrat à durée déterminée - 12 Mois\r\n\r...
# 1533  \r\nContrat à durée déterminée - 12 Mois\r\n\r...
# 1534  \r\nContrat à durée indéterminée\r\n\r\nContra...
#
#                                             Description  \
# 0     Dans le cadre d'un projet d'envergure avec un ...
# 1     Manpower ARMENTIERES recherche pour son client...
# 2     LHH Recruitment Solutions, cabinet de conseil ...
# 3     LHH Recruitment Solutions, cabinet de conseil ...
# 4     Sous la responsabilité du manager Data/IA, au ...
# ...                                                 ...
# 1530  Description :\r\nL'ISCOD, expert en formation ...
# 1531  Description :\r\nL'ISCOD, spécialiste de la fo...
# 1532  Description :\r\nL'ISCOD, spécialiste de la fo...
# 1533  En tant que Data Analyst, vous serez en charge...
# 1534  Safran est un groupe international de haute te...
#
#                                                 Salaire  \
# 0     Salaire brut : Annuel de 45000.0 Euros à 65000...
# 1                                 Salaire brut : Autres
# 2     Salaire brut : Annuel de 40000.0 Euros à 45000...
# 3                   Salaire brut : Salaire selon profil
# 4     Salaire brut : Annuel de 30000.0 Euros à 40000...
# ...                                                 ...
# 1530                                                NaN
# 1531                                                NaN
# 1532                                                NaN
# 1533                                                NaN
# 1534                                                NaN
#
#                                  Experience  \
# 0                                   5 An(s)
# 1                                   2 An(s)
# 2     3 An(s) - analyse données sociales...
# 3                                   1 An(s)
# 4                                   5 An(s)
# ...                                     ...
# 1530        Expérience souhaitée de 1 An(s)
# 1531        Expérience souhaitée de 1 An(s)
# 1532        Expérience souhaitée de 1 An(s)
# 1533                       Débutant accepté
# 1534                      Expérience exigée
#
#                                Entreprise
# 0             INFORMATIS TECHNOLOGY SYSTM
# 1                         MANPOWER FRANCE
# 2                                  ADECCO
# 3                           ADECCO FRANCE
# 4     SOCIETE DE FORMATIQUE ET FINANCIERE
# ...                                   ...
# 1530                        \r\nISCOD\r\n
# 1531                        \r\nISCOD\r\n
# 1532                        \r\nISCOD\r\n
# 1533                                  NaN
# 1534                                  NaN
#
# [1535 rows x 6 columns]

# %% [markdown]
# Modifications pour df1 :
# Rajouter une colonne département + lieu à null
# supprimer "\r" et "\n"
# Faire les mêmes changements que sur df2

# %%
posts_df2.drop_duplicates(subset=['Nom_poste', 'Entreprise', 'Description'], inplace=True)

# %%
import pandas as pd
import re

posts_df2['Contrat'] = posts_df2['Contrat'].str.replace(r'\s+', ' ', regex=True).str.lower()
posts_df2['Contrat'] = posts_df2['Contrat'].str.replace(r'\r\n+', ' ', regex=True)

def normaliser_contrat(contrat):
    if pd.isna(contrat):
        return "Non précisé"
    if "cdd" in contrat and ("apprentissage" in contrat or "professionnalisation" in contrat):
        return "CDD-alternance"
    if "cdd" in contrat or "déterminée" in contrat:
        return "CDD"
    if "cdi" in contrat or "indéterminée" in contrat:
        return "CDI"
    if "intérim" in contrat or "intérimaire" in contrat:
        return "Intérim"
    return "Autre"

posts_df2['Contrat'] = posts_df2['Contrat'].apply(normaliser_contrat)

# %%
def attribuer_groupe_metier(poste):
    poste = poste.lower()

    if any(x in poste for x in ['data engineer', 'ingénieur data', 'etl', 'développeur data']):
        return 'Data Engineer'
    elif any(x in poste for x in ['data analyst', 'analyste data']):
        return 'Data Analyst'
    elif any(x in poste for x in ['data scientist', 'machine learning', 'modélisation', 'ia', 'intelligence artificielle']):
        return 'Data Scientist'
    elif any(x in poste for x in ['bi', 'data manager', 'business intelligence', 'reporting', 'lead data']):
        return 'BI / Data Manager'
    elif 'architecte' in poste or 'architect' in poste or 'base de données' in poste:
        return 'Data Architect'
    elif any(x in poste for x in ['data steward', 'data quality']):
        return 'Data Steward'
    elif any(x in poste for x in ['consultant data', 'consultant en data', 'consultant données']):
        return 'Consultant Data'
    elif any(x in poste for x in ['développeur', 'dev', 'concepteur', 'application']):
        return 'Développeur SI / Logiciel'
    elif any(x in poste for x in ['système', 'réseau', 'infrastructure', 'administrateur', 'correspondant informatique']):
        return 'Administrateur Systèmes / Réseaux'
    elif any(x in poste for x in ['cybersécurité', 'sécurité', 'ssi', 'iso 27001', 'risques']):
        return 'Cybersécurité'
    elif 'urbaniste' in poste or 'architecture' in poste or 'systèmes d’information' in poste:
        return 'Architecte SI'
    elif any(x in poste for x in ['technicien', 'support', 'helpdesk', 'assistance']):
        return 'Support / Technicien'
    elif any(x in poste for x in ['chef de projet', 'scrum master', 'product owner', 'pilotage']):
        return 'Chef de projet IT'
    elif any(x in poste for x in ['consultant', 'moa', 'amoa']):
        return 'Consultant SI / MOA'

    else:
        return 'Autre'

# %%
import re

sections_robustes = {
    'missions': ['vos missions', 'missions', 'responsabilités', 'rôle', 'rôle attendu', 'activités principales'],
    'profil': ['profil', 'nous recherchons', 'candidat idéal', 'compétences attendues', 'profil recherché'],
    'stack_technique': ['stack technique', 'technologies', 'outils', 'environnement technique', 'framework', 'langages', 'logiciels', 'compétences requises']
}
sections_robustes['missions'].extend([
    'vous interviendrez',
    'objectifs',
    'vous serez amené à',
    'en charge de',
    'le travail consiste à',
    'tâches',
    'description et livrables de la prestation'
])
if 'skills' not in sections_robustes['stack_technique']:
    sections_robustes['stack_technique'].append('skills')

def extraire_bloc_robuste(description, sections):
    description = str(description).lower()
    description_clean = re.sub(r'[\n\r\t]+', ' ', description)  
    resultats = {key: None for key in sections.keys()}
    indices = {}

    for key, patterns in sections.items():
        for p in patterns:
            match = re.search(rf"{re.escape(p)}[\s:–\-]*", description_clean)
            if match:
                indices[key] = match.start()
                break

    tri_indices = sorted(indices.items(), key=lambda x: x[1])

    for i, (key, start) in enumerate(tri_indices):
        end = len(description_clean)
        if i + 1 < len(tri_indices):
            end = tri_indices[i + 1][1]
        bloc = description_clean[start:end].strip()
        resultats[key] = bloc

    return pd.Series(resultats)

extraits_robustes = posts_df2['Description'].fillna('').apply(lambda x: extraire_bloc_robuste(x, sections_robustes))

for col in extraits_robustes.columns:
    extraits_robustes[col] = extraits_robustes[col].str.replace(r'\s+', ' ', regex=True).str.strip()

posts_df = posts_df2.drop(columns=['missions', 'profil', 'stack_technique'], errors='ignore')  # supprimer anciens
posts_df = pd.concat([posts_df, extraits_robustes], axis=1)
def nettoyer_bloc(bloc, patterns):
    if pd.isna(bloc):
        return None
    for pattern in patterns:
        bloc = re.sub(rf"{re.escape(pattern)}[\s:–\-]*", '', bloc, flags=re.IGNORECASE)
    return bloc.strip()

titres_a_supprimer = {
    'missions': ['vos missions', 'missions', 'responsabilités', 'rôle', 'rôle attendu', 'activités principales'],
    'profil': ['profil', 'nous recherchons', 'candidat idéal', 'compétences attendues', 'profil recherché'],
    'stack_technique': ['stack technique', 'technologies', 'outils', 'environnement technique', 'framework', 'langages', 'logiciels', 'compétences requises']
}

for section, titres in titres_a_supprimer.items():
    posts_df[section] = posts_df[section].apply(lambda x: nettoyer_bloc(x, titres))
posts_df_filtred = posts_df[
    ~(posts_df['missions'].isna() & posts_df['profil'].isna() & posts_df['stack_technique'].isna())
]
posts_df_filtred = posts_df_filtred[posts_df_filtred['Description'].fillna('').str.len() > 50]

colonnes_a_nettoyer = ['Description', 'missions', 'profil', 'stack_technique']
for col in colonnes_a_nettoyer:
    posts_df_filtred[col] = posts_df_filtred[col].astype(str).str.replace(r'\s+', ' ', regex=True).str.strip()

posts_df_filtred['groupe_metier'] = posts_df_filtred['Nom_poste'].fillna('').apply(attribuer_groupe_metier)

posts_df_filtred
# Out:
#                                               Nom_poste  \
# 0     Data Engineer/Quant Développeur - Poste en cli...
# 1                    Chef du pôle Data Innovation (H/F)
# 2       Chef de Projet Data Center - Confirmé - MOE H/F
# 3                      Data Analyst en alternance (H/F)
# 4                                    Data manager (H/F)
# ...                                                 ...
# 1576  INGÉNIEUR R&D / DATA SCIENTIST - CDI CLIENT FI...
# 1577                                 Ingénieur Data H/F
# 1578                Chef de Projet/AMOA Data Galaxy H/F
# 1579  [Luxe/Retail] / Consultant Master Data Produit...
# 1580                    Consultant Data Gouvernance H/F
#
#                         Lieu Contrat  \
# 0                35 - RENNES     CDD
# 1                 29 - BREST     CDD
# 2              75 - PARIS 01     CDD
# 3     35 - NOYAL SUR VILAINE     CDD
# 4              Ile-de-France   Autre
# ...                      ...     ...
# 1576          93 - MONTREUIL     CDD
# 1577  78 - MAGNY LES HAMEAUX     CDD
# 1578           Ile-de-France     CDD
# 1579           75 - PARIS 10     CDD
# 1580         76 - MOULINEAUX     CDD
#
#                                             Description  \
# 0     La société: Fond gérant plus 10 milliards doll...
# 1     Notre client : L'agence nationale de traitemen...
# 2     POSTE : Chef de Projet Data Center - Confirmé ...
# 3     Vous intégrerez la Direction Logistique d'Ayve...
# 4     Data Scientiste GenAI pour le AI LAB RAG 450 e...
# ...                                                 ...
# 1576  Nous recherchons pour le compte de notre clien...
# 1577  Fondé en 1996, Claranet est un acteur majeur d...
# 1578  Activus Group recherche un Chef de Projet/AMOA...
# 1579  Cabinet à forte croissance, Cenova accompagne ...
# 1580  Fondé en 1996, Claranet est un acteur majeur d...
#
#                         Salaire                    Experience    Entreprise  \
# 0                           NaN  Expérience exigée de 3 An(s)           NaN
# 1     Rémunération selon profil                       7 An(s)       ELIGERA
# 2                           NaN             Expérience exigée  Egis  Groupe
# 3                           NaN              Débutant accepté        Temsys
# 4                           NaN  Expérience exigée de 2 An(s)  BI SOLUTIONS
# ...                         ...                           ...           ...
# 1576                        NaN  Expérience exigée de 3 An(s)      Expectra
# 1577                        NaN              Débutant accepté           NaN
# 1578                        NaN             Expérience exigée           NaN
# 1579                        NaN             Expérience exigée           NaN
# 1580                        NaN              Débutant accepté           NaN
#
#                                                missions  \
# 0     * rechercher, concevoir et intégrer de nouveau...
# 1     pilotage stratégique de la donnée : o construi...
# 2     coordination et pilotage des études de concept...
# 3     . progressivement, vous gagnerez en autonomie ...
# 4                                                  None
# ...                                                 ...
# 1576  vous interviendrez également sur le support cl...
# 1577  * cadrage des besoins clients : collaborer ave...
# 1578                                tâches sur l'outil.
# 1579  et une réelle proximité managériale pour vous ...
# 1580  principales : évaluation des besoins en gouver...
#
#                                                  profil  \
# 0     recherché : * ecole dingénieur * minimum 3 ann...
# 1     recherché : - maitrise des si, des environneme...
# 2     si vous êtes un professionnel chevronné, prêt ...
# 3                                                  None
# 4     recherché : formation supérieure en informatiq...
# ...                                                 ...
# 1576  pour le compte de notre client un fabricant de...
# 1577                                               None
# 1578  recherché de minimum 4 ans d'expérience, capab...
# 1579  diplômé(e) d'une ecole de commerce ou d'ingéni...
# 1580                                               None
#
#                                         stack_technique        groupe_metier
# 0     internes de notre client afin d'aider les équi...        Data Engineer
# 1     et à l'innovation. - pilotage technique opérat...                Autre
# 2     internes, suivre l'évolution des contrats et d...    Chef de projet IT
# 3     permettant d'optimiser les traitements des don...         Data Analyst
# 4         expérience genai, graphrag souhaité) 450 e/ j    BI / Data Manager
# ...                                                 ...                  ...
# 1576  en lien avec l'activité de l'équipe ia rédiger...       Data Scientist
# 1577  comme apache kafka ou spark). * sécurité des d...        Data Engineer
# 1578                                               None    Chef de projet IT
# 1579  gestion de projets (jira.) & data visualisatio...  Consultant SI / MOA
# 1580  liés à la gouvernance des données. gestion des...      Consultant Data
#
# [1539 rows x 11 columns]

# %%
#df1

posts_df1_cleaned = posts_df1
for col in ['Nom_poste', 'Contrat', 'Entreprise', 'Description']:
    posts_df1_cleaned[col] = posts_df1_cleaned[col].astype(str).str.replace(r'<.*?>', '', regex=True)
    posts_df1_cleaned[col] = posts_df1_cleaned[col].str.replace(r'\s+', ' ', regex=True).str.strip()

posts_df1_cleaned = posts_df1_cleaned.drop(columns=['Salaire'])

posts_df1_cleaned['Contrat'] = posts_df1_cleaned['Contrat'].str.lower()
posts_df1_cleaned['Contrat'] = posts_df1_cleaned['Contrat'].apply(normaliser_contrat)

extraits_base = posts_df1_cleaned['Description'].fillna('').apply(lambda x: extraire_bloc_robuste(x, sections_robustes))
posts_df1_cleaned = pd.concat([posts_df1_cleaned, extraits_base], axis=1)

posts_df1_cleaned['groupe_metier'] = posts_df1_cleaned['Nom_poste'].fillna('').apply(attribuer_groupe_metier)

posts_df1_cleaned['Lieu'] = 'France'

posts_df1_cleaned
# Out:
#                                               Nom_poste  Contrat  \
# 0                                DBA SQL/Big Data (H/F)      CDI
# 1                                    Data analyst (H/F)  Intérim
# 2     Contrôle de gestion données sociales RH/Data A...      CDI
# 3                      Comptable /Data contrôleur (h/f)      CDI
# 4                     Ingénieur Data GCP Confirmé (H/F)      CDI
# ...                                                 ...      ...
# 1530  Alternance Ingénieur Data analyst - Munster (H/F)      CDD
# 1531  Alternance Data analyst/testeur - Paris La Déf...      CDD
# 1532   Alternance Data analyst - Toussus-le-Noble (H/F)      CDD
# 1533                  Data Analyst - Biomasse - CDD H/F      CDD
# 1534                   Stream leader data ibp f/h (H/F)      CDD
#
#                                             Description  \
# 0     Dans le cadre d'un projet d'envergure avec un ...
# 1     Manpower ARMENTIERES recherche pour son client...
# 2     LHH Recruitment Solutions, cabinet de conseil ...
# 3     LHH Recruitment Solutions, cabinet de conseil ...
# 4     Sous la responsabilité du manager Data/IA, au ...
# ...                                                 ...
# 1530  Description : L'ISCOD, expert en formation Dig...
# 1531  Description : L'ISCOD, spécialiste de la forma...
# 1532  Description : L'ISCOD, spécialiste de la forma...
# 1533  En tant que Data Analyst, vous serez en charge...
# 1534  Safran est un groupe international de haute te...
#
#                                  Experience  \
# 0                                   5 An(s)
# 1                                   2 An(s)
# 2     3 An(s) - analyse données sociales...
# 3                                   1 An(s)
# 4                                   5 An(s)
# ...                                     ...
# 1530        Expérience souhaitée de 1 An(s)
# 1531        Expérience souhaitée de 1 An(s)
# 1532        Expérience souhaitée de 1 An(s)
# 1533                       Débutant accepté
# 1534                      Expérience exigée
#
#                                Entreprise  \
# 0             INFORMATIS TECHNOLOGY SYSTM
# 1                         MANPOWER FRANCE
# 2                                  ADECCO
# 3                           ADECCO FRANCE
# 4     SOCIETE DE FORMATIQUE ET FINANCIERE
# ...                                   ...
# 1530                                ISCOD
# 1531                                ISCOD
# 1532                                ISCOD
# 1533                                  nan
# 1534                                  nan
#
#                                                missions  \
# 0     vos missions en tant que dba développeur sql/b...
# 1                                                  None
# 2     vos missions : - mettre en place et piloter de...
# 3     missions de tenue comptable, déclaration des t...
# 4     vos missions sont les suivantes : 1. structura...
# ...                                                 ...
# 1530  missions : en tant qu?apprenti(e), tu auras un...
# 1531  missions : analyser les opportunités et élabor...
# 1532  missions : traitement et intégration des donné...
# 1533  vos missions incluront : collecte, nettoyage e...
# 1534  missionsafran aircraft engines dispose d'un ré...
#
#                                                  profil  \
# 0     nous recherchons un dba développeur sql/big da...
# 1                                                  None
# 2                                                  None
# 3     profil base 39h de formation supérieure en com...
# 4     profil idéal. dès votre arrivée, un parcours d...
# ...                                                 ...
# 1530  profil : profiltu es actuellement inscrit(e) e...
# 1531  profil : dernière année de master en école de ...
# 1532  profil : compétences techniques :maîtrise de s...
# 1533                                               None
# 1534                                               None
#
#                                         stack_technique      groupe_metier  \
# 0     compétences requises diplôme bac+5 en informat...  BI / Data Manager
# 1     outils de data mining et de modélisation stati...       Data Analyst
# 2     outils performants pour répondre aux ambitions...       Data Analyst
# 3     outils informatiques et le digital ! vous avez...              Autre
# 4     outils d'elt les plus appropriés, tels que dbt...      Data Engineer
# ...                                                 ...                ...
# 1530  technologies avancées pour optimiser ses proce...      Data Engineer
# 1531  outils rhassurer le support aux utilisateurs l...       Data Analyst
# 1532  technologies.pourquoi rejoindre l'iscod ? étud...       Data Analyst
# 1533  outils d'analyse de données : sql, python, exc...       Data Analyst
# 1534                                               None              Autre
#
#         Lieu
# 0     France
# 1     France
# 2     France
# 3     France
# 4     France
# ...      ...
# 1530  France
# 1531  France
# 1532  France
# 1533  France
# 1534  France
#
# [1535 rows x 10 columns]

# %%
df_combined_posts = pd.concat([posts_df1_cleaned, posts_df_filtred], axis=0, ignore_index=True)
df_cleaned_combined_posts = df_combined_posts

df_cleaned_combined_posts.drop(columns=['Salaire'], inplace=True)

def convert_experience_en_mois(texte):
    if pd.isna(texte):
        return None
    texte = str(texte).lower()
    if "débutant" in texte:
        return 0
    match = re.search(r'(\d+)\s*an', texte)
    if match:
        return int(match.group(1)) * 12
    return None

df_cleaned_combined_posts['experience_mois'] = df_cleaned_combined_posts['Experience'].apply(convert_experience_en_mois)
duplicated_desc = df_cleaned_combined_posts.duplicated(subset='Description', keep=False)
condition_to_drop = duplicated_desc & (df_cleaned_combined_posts['Lieu'] == 'France')
df_clean_offres = df_cleaned_combined_posts[~condition_to_drop].reset_index(drop=True)



df_clean_offres
# Out:
#                                               Nom_poste Contrat  \
# 0                 Chargé(e) de data marketing F/H (H/F)     CDI
# 1                       Ingénieur base de données (H/F)     CDD
# 2     Senior consultant data et transformation digit...     CDD
# 3                                    Data analyst (H/F)   Autre
# 4             Développeur / Développeuse Big Data (H/F)   Autre
# ...                                                 ...     ...
# 2235  INGÉNIEUR R&D / DATA SCIENTIST - CDI CLIENT FI...     CDD
# 2236                                 Ingénieur Data H/F     CDD
# 2237                Chef de Projet/AMOA Data Galaxy H/F     CDD
# 2238  [Luxe/Retail] / Consultant Master Data Produit...     CDD
# 2239                    Consultant Data Gouvernance H/F     CDD
#
#                                             Description  \
# 0     Le Groupe SAMSE est un groupe Audacieux et Pas...
# 1     L'ingénieur(e) devra organiser de manière stru...
# 2     QUI SOMMES-NOUS ?Le site de Vélizy regroupe le...
# 3     *Conception, réalisation et documentation de d...
# 4     Description de la mission : - Participer au bu...
# ...                                                 ...
# 2235  Nous recherchons pour le compte de notre clien...
# 2236  Fondé en 1996, Claranet est un acteur majeur d...
# 2237  Activus Group recherche un Chef de Projet/AMOA...
# 2238  Cabinet à forte croissance, Cenova accompagne ...
# 2239  Fondé en 1996, Claranet est un acteur majeur d...
#
#                         Experience   Entreprise  \
# 0                          1 An(s)        SAMSE
# 1                           4 Mois          nan
# 2                 Débutant accepté          nan
# 3     Expérience exigée de 5 An(s)    Mindquest
# 4     Expérience exigée de 5 An(s)  HAYS MEDIAS
# ...                            ...          ...
# 2235  Expérience exigée de 3 An(s)     Expectra
# 2236              Débutant accepté          NaN
# 2237             Expérience exigée          NaN
# 2238             Expérience exigée          NaN
# 2239              Débutant accepté          NaN
#
#                                                missions  \
# 0     missions seront variées et stimulantes : analy...
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 2235  vous interviendrez également sur le support cl...
# 2236  * cadrage des besoins clients : collaborer ave...
# 2237                                tâches sur l'outil.
# 2238  et une réelle proximité managériale pour vous ...
# 2239  principales : évaluation des besoins en gouver...
#
#                                                  profil  \
# 0     nous recherchons un(e) chargé(e) de data marke...
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 2235  pour le compte de notre client un fabricant de...
# 2236                                               None
# 2237  recherché de minimum 4 ans d'expérience, capab...
# 2238  diplômé(e) d'une ecole de commerce ou d'ingéni...
# 2239                                               None
#
#                                         stack_technique        groupe_metier  \
# 0                                                  None                Autre
# 1                                                  None       Data Architect
# 2                                                  None      Consultant Data
# 3                                                  None         Data Analyst
# 4                                                  None    BI / Data Manager
# ...                                                 ...                  ...
# 2235  en lien avec l'activité de l'équipe ia rédiger...       Data Scientist
# 2236  comme apache kafka ou spark). * sécurité des d...        Data Engineer
# 2237                                               None    Chef de projet IT
# 2238  gestion de projets (jira.) & data visualisatio...  Consultant SI / MOA
# 2239  liés à la gouvernance des données. gestion des...      Consultant Data
#
#                         Lieu  experience_mois
# 0                     France             12.0
# 1                     France              NaN
# 2                     France              0.0
# 3                     France             60.0
# 4                     France             60.0
# ...                      ...              ...
# 2235          93 - MONTREUIL             36.0
# 2236  78 - MAGNY LES HAMEAUX              0.0
# 2237           Ile-de-France              NaN
# 2238           75 - PARIS 10              NaN
# 2239         76 - MOULINEAUX              0.0
#
# [2240 rows x 11 columns]

# %%
output_path = "Data/df_clean_offres.xlsx"
df_clean_offres.to_excel(output_path, index=False)

# %%
output_path = "Data/df_clean_offres_csv.csv"
df_clean_offres.to_csv(output_path, index=False)

# %% [markdown]
# Modification à faire pour le fichier excel:
#
# - Suppression des doublons
#
# - Nom du poste : à regrouper par métier ou groupe métier
# - Lieu : split la colonne du lieu avec le séparateur '-' pour récupérer le code du département
#         "Attention ! Ile_de_France et Provence-Alpes-Côte d'Azur on remplace par des codes"
#         "Supprimer canada et mettre 00 pour France"
#
# - Contart :
#         - Suprrimer les "\n"
#         - Ceux qui contiennent "CDD & apprentissage" ou "CDD-professionnalisation"--> "CDD-alternance'
#         - Ceux qui contiennent "CDD & travail" ou le mot "déterminée" --> "CDD"
#         - les mots "CDI" ou "indéterminée"--> "CDI"
#         - Les mots "Intérim" ou 'intérimaire" --> "Intérim"
#
# - Description :
#         - Supprimer les "\n"
#         - Regrouper "Vos missions", "Notre stack technique", "Profil", "Technologies", "outils", "livrables", "Compétences"
#
# - Salaire :
#         - a supprimer
# - Experience :
#         - A convertir tout en mois
#         - Mettre "Débutant" à 0.

# %% [markdown]
# ### Nettoyage et transformation de dataset Profil

# %% [markdown]
# Exploration de données

# %%
df1_profil = pd.read_csv('Data/combined_no_duplicates_cv.csv')
df2_profil = pd.read_excel('Data/ProfilF.xlsx')

# %%
df1_profil
# Out:
#                                                 Profil Lieu_de_recherche  \
# 0    Ingénieur en sécurité  et administration systè...    France entière
# 1    Ingénieur IT Junior – Development | Data | BI ...    France entière
# 2    Développeur Python spécialisé en Data Engineering    France entière
# 3                                       Data Scientist    France entière
# 4             Ingénieur Data & IA | Développeur Python    France entière
# ..                                                 ...               ...
# 733      Mathématicien en reconversion professionnelle    France entière
# 734                                    Energy Engineer    France entière
# 735                        Chef de projet informatique    France entière
# 736  De formation RH, je souhaite explorer d'autres...    France entière
# 737        Developper intelligence artificielle junior    France entière
#
#     Disponibilité                                       Points_forts  \
# 0       immédiate  Administration des systèmes et réseaux\r\nArch...
# 1       immédiate  Concevoir et gérer un projet\r\nData engineer\...
# 2       immédiate  Anglais technique\r\nData engineer\r\nIntellig...
# 3       immédiate  Backend Java, Python, C++, PHP, SQL, NoSQL\r\n...
# 4       immédiate  Big data Analytics\r\nConcevoir et gérer un pr...
# ..            ...                                                ...
# 733     immédiate  S'adapter aux changements\r\nTravailler en équ...
# 734     immédiate  Concevoir et gérer un projet\r\nDéfinir les ca...
# 735     immédiate  Animer, coordonner une équipe\r\nConcevoir et ...
# 736     immédiate  Élaborer, suivre et piloter un budget\r\nGesti...
# 737     immédiate  Définir et faire évoluer des procédés de trait...
#
#                                             Expérience  \
# 0    Consultant technique\r\n\r\n|\r\nSRA Afrique (...
# 1           Data analysis\r\n\r\n|\r\n (Toulon-France)
# 2    MIAGE DAta et Business Intelligence (DABI)\r\n...
# 3    Data Scientist\r\n\r\n|\r\ntouwi (Caen)Cette E...
# 4    Ingénieur en Machine Learning (stage)\r\n\r\n|...
# ..                                                 ...
# 733  \r\nIntervenant en Mathématiques\r\n\r\n|\r\nC...
# 734  \r\nDouble diplome Management des sytèmes éner...
# 735  \r\nAssistant chargé de projet interne\r\n\r\n...
# 736     \r\nConsultant en Recrutement\r\n\r\n|\r\nHAYS
# 737    \r\nBarman\r\n\r\n|\r\nRestaurant Jardin d'Asie
#
#                                             Compétence
# 0    Gérer les risques de cybersécurité\r\n(Avancé)...
# 1    Algorithmique\r\n(Avancé)\r\nAnalyse statistiq...
# 2    Algorithmique\r\nAnglais technique\r\nArchitec...
# 3    Algorithmique\r\nDocker\r\nGitHub\r\nJava\r\nJ...
# 4    Algorithmique\r\nAnalyse statistique\r\nBig da...
# ..                                                 ...
# 733  Adapter un parcours ou une séquence pédagogiqu...
# 734  Concevoir l'architecture d'un système, d'un ré...
# 735  After Effects\r\n(Intermédiaire)\r\nCSS\r\n(Av...
# 736  Analyser les besoins de l'entreprise en format...
# 737  Animer, coordonner une équipe\r\nCaractéristiq...
#
# [738 rows x 6 columns]

# %%
df1_profil.describe()
# Out:
#               Profil Lieu_de_recherche Disponibilité  \
# count            738               738           738
# unique           619                 1             1
# top     Data Analyst    France entière     immédiate
# freq              26               738           738
#
#                                              Points_forts    Expérience  \
# count                                                 556           734
# unique                                                536           732
# top     Analyser, exploiter, structurer des données\r\...  Data Analyst
# freq                                                    2             2
#
#                                                Compétence
# count                                                 718
# unique                                                695
# top     Rédiger un cahier des charges, des spécificati...
# freq                                                    4

# %%
df2_profil.describe()
# Out:
#               Profil Lieu_de_recherche Disponibilité Points_forts  \
# count           1418              1418          1418         1073
# unique           678                 1             1          583
# top     Data Analyst    France entière     immédiate      Anglais
# freq              47              1418          1418            5
#
#           Expérience                                         Compétence
# count           1410                                               1376
# unique           873                                                761
# top     Data Analyst  Rédiger un cahier des charges, des spécificati...
# freq               5                                                  8

# %%
df1_profil.columns
# Out:
# Index(['Profil', 'Lieu_de_recherche', 'Disponibilité', 'Points_forts',
#        'Expérience', 'Compétence'],
#       dtype='object')

# %%
df2_profil.columns
# Out:
# Index(['Profil', 'Lieu_de_recherche', 'Disponibilité', 'Points_forts',
#        'Expérience', 'Compétence'],
#       dtype='object')

# %% [markdown]
# Combinaison de deux dataset et suppression de doublons

# %%
df_profil_combined = pd.concat([df1_profil, df2_profil], ignore_index=True)

# %%
df_profil_combined.describe()
# Out:
#               Profil Lieu_de_recherche Disponibilité Points_forts  \
# count           2156              2156          2156         1629
# unique           678                 1             1         1112
# top     Data Analyst    France entière     immédiate      Anglais
# freq              73              2156          2156            7
#
#           Expérience                                         Compétence
# count           2144                                               2094
# unique          1552                                               1440
# top     Data Analyst  Rédiger un cahier des charges, des spécificati...
# freq               7                                                 12

# %%
df_profile_cleaned = df_profil_combined.drop_duplicates( subset=['Points_forts', 'Expérience'])

# %%
df_profile_cleaned.describe()
# Out:
#               Profil Lieu_de_recherche Disponibilité Points_forts  \
# count           1613              1613          1613         1235
# unique           677                 1             1         1112
# top     Data Analyst    France entière     immédiate      Anglais
# freq              57              1613          1613            6
#
#           Expérience                                         Compétence
# count           1609                                               1569
# unique          1552                                               1406
# top     Data Analyst  Rédiger un cahier des charges, des spécificati...
# freq               5                                                  8

# %% [markdown]
# Nettoyage des colonnes Points_forts, Expérience, Compétence

# %%
import re
import string

def nettoyer_texte(texte):
    if pd.isna(texte):
        return ""
    texte = re.sub(r'[\r\n\t]+', ' ', texte)
    texte = texte.translate(str.maketrans('', '', string.punctuation))
    texte = re.sub(r'\s+', ' ', texte)
    return texte.strip()

colonnes_a_nettoyer = ['Points_forts', 'Expérience', 'Compétence']

for col in colonnes_a_nettoyer:
    df_profile_cleaned[col] = df_profile_cleaned[col].apply(nettoyer_texte)
# Out:
# C:\Users\ahmed\AppData\Local\Temp\ipykernel_18204\1926821188.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_profile_cleaned[col] = df_profile_cleaned[col].apply(nettoyer_texte)

# %%
df_profile_cleaned
# Out:
#                                                  Profil Lieu_de_recherche  \
# 0     Ingénieur en sécurité  et administration systè...    France entière
# 1     Ingénieur IT Junior – Development | Data | BI ...    France entière
# 2     Développeur Python spécialisé en Data Engineering    France entière
# 3                                        Data Scientist    France entière
# 4              Ingénieur Data & IA | Développeur Python    France entière
# ...                                                 ...               ...
# 2151      Mathématicien en reconversion professionnelle    France entière
# 2152                                    Energy Engineer    France entière
# 2153                        Chef de projet informatique    France entière
# 2154  De formation RH, je souhaite explorer d'autres...    France entière
# 2155        Developper intelligence artificielle junior    France entière
#
#      Disponibilité                                       Points_forts  \
# 0        immédiate  Administration des systèmes et réseaux Archite...
# 1        immédiate  Concevoir et gérer un projet Data engineer Big...
# 2        immédiate  Anglais technique Data engineer Intelligence a...
# 3        immédiate  Backend Java Python C PHP SQL NoSQL Data Scien...
# 4        immédiate  Big data Analytics Concevoir et gérer un proje...
# ...            ...                                                ...
# 2151     immédiate  Sadapter aux changements Travailler en équipe ...
# 2152     immédiate  Concevoir et gérer un projet Définir les carac...
# 2153     immédiate  Animer coordonner une équipe Concevoir et gére...
# 2154     immédiate  Élaborer suivre et piloter un budget Gestion b...
# 2155     immédiate  Définir et faire évoluer des procédés de trait...
#
#                                              Expérience  \
# 0     Consultant technique SRA Afrique Casablanca Maroc
# 1                            Data analysis ToulonFrance
# 2     MIAGE DAta et Business Intelligence DABI Bac5 ...
# 3     Data Scientist touwi CaenCette Expérience cont...
# 4     Ingénieur en Machine Learning stage Decathlon ...
# ...                                                 ...
# 2151  Intervenant en Mathématiques Collège Saint Jos...
# 2152  Double diplome Management des sytèmes énergéti...
# 2153  Assistant chargé de projet interne H3 hitema p...
# 2154                     Consultant en Recrutement HAYS
# 2155                     Barman Restaurant Jardin dAsie
#
#                                              Compétence
# 0     Gérer les risques de cybersécurité Avancé Sass...
# 1     Algorithmique Avancé Analyse statistique Avanc...
# 2     Algorithmique Anglais technique Architecture w...
# 3     Algorithmique Docker GitHub Java Javascript Ku...
# 4     Algorithmique Analyse statistique Big data Ana...
# ...                                                 ...
# 2151  Adapter un parcours ou une séquence pédagogiqu...
# 2152  Concevoir larchitecture dun système dun réseau...
# 2153  After Effects Intermédiaire CSS Avancé GitHub ...
# 2154  Analyser les besoins de lentreprise en formati...
# 2155  Animer coordonner une équipe Caractéristiques ...
#
# [1613 rows x 6 columns]

# %% [markdown]
# suppresion des profils qui ont des titres exclu de l'IT

# %%
mots_cles_exclus = [
    "ressources humaines", "rh", "recrutement", "recruteur",
    "marketing", "communication", "finance", "comptabilité",
    "juridique", "assistant", "assistante", "commercial", "vente",
    "banque", "audit", "contrôle de gestion", "gestionnaire", "achats", "relation client"
]

def est_exclu(profil):
    if pd.isna(profil):
        return False
    profil_lower = profil.lower()
    return any(mot in profil_lower for mot in mots_cles_exclus)

df_profile_cleaned = df_profile_cleaned[~df_profile_cleaned['Profil'].apply(est_exclu)].copy()

# %%
df_profile_cleaned
# Out:
#                                                  Profil Lieu_de_recherche  \
# 0     Ingénieur en sécurité  et administration systè...    France entière
# 1     Ingénieur IT Junior – Development | Data | BI ...    France entière
# 2     Développeur Python spécialisé en Data Engineering    France entière
# 3                                        Data Scientist    France entière
# 4              Ingénieur Data & IA | Développeur Python    France entière
# ...                                                 ...               ...
# 2150  Ingénieur en systèmes intelligents avec des co...    France entière
# 2151      Mathématicien en reconversion professionnelle    France entière
# 2152                                    Energy Engineer    France entière
# 2153                        Chef de projet informatique    France entière
# 2155        Developper intelligence artificielle junior    France entière
#
#      Disponibilité                                       Points_forts  \
# 0        immédiate  Administration des systèmes et réseaux Archite...
# 1        immédiate  Concevoir et gérer un projet Data engineer Big...
# 2        immédiate  Anglais technique Data engineer Intelligence a...
# 3        immédiate  Backend Java Python C PHP SQL NoSQL Data Scien...
# 4        immédiate  Big data Analytics Concevoir et gérer un proje...
# ...            ...                                                ...
# 2150     immédiate
# 2151     immédiate  Sadapter aux changements Travailler en équipe ...
# 2152     immédiate  Concevoir et gérer un projet Définir les carac...
# 2153     immédiate  Animer coordonner une équipe Concevoir et gére...
# 2155     immédiate  Définir et faire évoluer des procédés de trait...
#
#                                              Expérience  \
# 0     Consultant technique SRA Afrique Casablanca Maroc
# 1                            Data analysis ToulonFrance
# 2     MIAGE DAta et Business Intelligence DABI Bac5 ...
# 3     Data Scientist touwi CaenCette Expérience cont...
# 4     Ingénieur en Machine Learning stage Decathlon ...
# ...                                                 ...
# 2150  Master Automatique Robotique Parcours Ingénier...
# 2151  Intervenant en Mathématiques Collège Saint Jos...
# 2152  Double diplome Management des sytèmes énergéti...
# 2153  Assistant chargé de projet interne H3 hitema p...
# 2155                     Barman Restaurant Jardin dAsie
#
#                                              Compétence
# 0     Gérer les risques de cybersécurité Avancé Sass...
# 1     Algorithmique Avancé Analyse statistique Avanc...
# 2     Algorithmique Anglais technique Architecture w...
# 3     Algorithmique Docker GitHub Java Javascript Ku...
# 4     Algorithmique Analyse statistique Big data Ana...
# ...                                                 ...
# 2150
# 2151  Adapter un parcours ou une séquence pédagogiqu...
# 2152  Concevoir larchitecture dun système dun réseau...
# 2153  After Effects Intermédiaire CSS Avancé GitHub ...
# 2155  Animer coordonner une équipe Caractéristiques ...
#
# [1455 rows x 6 columns]

# %% [markdown]
# extraction des mots clé de contrat de la colonne Profil

# %%
import re

contrats_clé = [
    "CDI", "CDD", "Alternance", "Apprentissage",
    "contrat d'apprentissage", "contrat de professionnalisation"
]

def extraire_contrat(texte):   
    if pd.isna(texte):
        return ""
    contrats_trouvé = [c for c in contrats_clé if re.search(rf'\b{re.escape(c)}\b', texte, flags=re.IGNORECASE)]
    return ", ".join(set(contrats_trouvé))

df_profile_cleaned['Contrat'] = df_profile_cleaned['Profil'].apply(extraire_contrat)

# %%
df_profile_cleaned['Contrat'].value_counts()
# Out:
# Contrat
#                         1351
# CDI                       40
# Alternance                28
# Apprentissage             16
# CDD, CDI                  14
# Alternance, CDD, CDI       6
# Name: count, dtype: int64

# %%
df_profile_cleaned.describe()
# Out:
#               Profil Lieu_de_recherche Disponibilité Points_forts Expérience  \
# count           1455              1455          1455         1455       1455
# unique           607                 1             1          528        660
# top     Data Analyst    France entière     immédiate
# freq              57              1455          1455          343          6
#
#        Compétence Contrat
# count        1455    1455
# unique        689       6
# top
# freq           39    1351

# %% [markdown]
# Regroupement des métiers

# %%
def regrouper_metier(profil):
    if pd.isna(profil):
        return "Inconnu"

    profil_lower = profil.lower()

    if "data analyst" in profil_lower:
        return "Data Analyst"
    elif "data engineer" in profil_lower:
        return "Data Engineer"
    elif "data scientist" in profil_lower:
        return "Data Scientist"
    elif "développeur" in profil_lower or "developer" in profil_lower:
        return "Développeur"
    elif "ingénieur logiciel" in profil_lower or "software engineer" in profil_lower:
        return "Ingénieur Logiciel"
    elif "admin" in profil_lower and ("système" in profil_lower or "réseau" in profil_lower):
        return "Administrateur Systèmes/Réseaux"
    elif "devops" in profil_lower:
        return "DevOps"
    elif "consultant bi" in profil_lower or "business intelligence" in profil_lower:
        return "Consultant BI"
    elif "architecte" in profil_lower:
        return "Architecte SI"
    elif "chef de projet" in profil_lower or "scrum master" in profil_lower:
        return "Chef de projet/Scrum Master"
    elif "cybersécurité" in profil_lower or "sécurité informatique" in profil_lower:
        return "Cybersécurité"
    else:
        return "Autre"

df_profile_cleaned["Metier_regroupe"] = df_profile_cleaned["Profil"].apply(regrouper_metier)

# %%
df_profile_cleaned
# Out:
#                                                  Profil Lieu_de_recherche  \
# 0     Ingénieur en sécurité  et administration systè...    France entière
# 1     Ingénieur IT Junior – Development | Data | BI ...    France entière
# 2     Développeur Python spécialisé en Data Engineering    France entière
# 3                                        Data Scientist    France entière
# 4              Ingénieur Data & IA | Développeur Python    France entière
# ...                                                 ...               ...
# 2150  Ingénieur en systèmes intelligents avec des co...    France entière
# 2151      Mathématicien en reconversion professionnelle    France entière
# 2152                                    Energy Engineer    France entière
# 2153                        Chef de projet informatique    France entière
# 2155        Developper intelligence artificielle junior    France entière
#
#      Disponibilité                                       Points_forts  \
# 0        immédiate  Administration des systèmes et réseaux Archite...
# 1        immédiate  Concevoir et gérer un projet Data engineer Big...
# 2        immédiate  Anglais technique Data engineer Intelligence a...
# 3        immédiate  Backend Java Python C PHP SQL NoSQL Data Scien...
# 4        immédiate  Big data Analytics Concevoir et gérer un proje...
# ...            ...                                                ...
# 2150     immédiate
# 2151     immédiate  Sadapter aux changements Travailler en équipe ...
# 2152     immédiate  Concevoir et gérer un projet Définir les carac...
# 2153     immédiate  Animer coordonner une équipe Concevoir et gére...
# 2155     immédiate  Définir et faire évoluer des procédés de trait...
#
#                                              Expérience  \
# 0     Consultant technique SRA Afrique Casablanca Maroc
# 1                            Data analysis ToulonFrance
# 2     MIAGE DAta et Business Intelligence DABI Bac5 ...
# 3     Data Scientist touwi CaenCette Expérience cont...
# 4     Ingénieur en Machine Learning stage Decathlon ...
# ...                                                 ...
# 2150  Master Automatique Robotique Parcours Ingénier...
# 2151  Intervenant en Mathématiques Collège Saint Jos...
# 2152  Double diplome Management des sytèmes énergéti...
# 2153  Assistant chargé de projet interne H3 hitema p...
# 2155                     Barman Restaurant Jardin dAsie
#
#                                              Compétence        Contrat  \
# 0     Gérer les risques de cybersécurité Avancé Sass...
# 1     Algorithmique Avancé Analyse statistique Avanc...
# 2     Algorithmique Anglais technique Architecture w...
# 3     Algorithmique Docker GitHub Java Javascript Ku...
# 4     Algorithmique Analyse statistique Big data Ana...
# ...                                                 ...            ...
# 2150                                                     Apprentissage
# 2151  Adapter un parcours ou une séquence pédagogiqu...
# 2152  Concevoir larchitecture dun système dun réseau...
# 2153  After Effects Intermédiaire CSS Avancé GitHub ...
# 2155  Animer coordonner une équipe Caractéristiques ...
#
#                       Metier_regroupe
# 0     Administrateur Systèmes/Réseaux
# 1                               Autre
# 2                       Data Engineer
# 3                      Data Scientist
# 4                         Développeur
# ...                               ...
# 2150                            Autre
# 2151                            Autre
# 2152                            Autre
# 2153      Chef de projet/Scrum Master
# 2155                            Autre
#
# [1455 rows x 8 columns]

# %%
df_profile_cleaned.describe()
# Out:
#               Profil Lieu_de_recherche Disponibilité Points_forts Expérience  \
# count           1455              1455          1455         1455       1455
# unique           607                 1             1          528        660
# top     Data Analyst    France entière     immédiate
# freq              57              1455          1455          343          6
#
#        Compétence Contrat Metier_regroupe
# count        1455    1455            1455
# unique        689       6              12
# top                                 Autre
# freq           39    1351             806

# %% [markdown]
# Effacer les doublons selon la colonne Compétence

# %%
df_profile_cleaned = df_profile_cleaned.drop_duplicates(subset='Compétence', keep='first')

# %%
df_profile_cleaned.describe()
# Out:
#               Profil Lieu_de_recherche Disponibilité Points_forts Expérience  \
# count            689               689           689          689        689
# unique           586                 1             1          516        635
# top     Data Analyst    France entière     immédiate
# freq              24               689           689          160          3
#
#                                                Compétence Contrat  \
# count                                                 689     689
# unique                                                689       6
# top     Analyse de données expérimentales Comptabilité...
# freq                                                    1     639
#
#        Metier_regroupe
# count              689
# unique              12
# top              Autre
# freq               376

# %%
df_profile_cleaned.to_csv("Data/profile_sans_doublons_2.csv", index=False)

# %%
df_profile_cleaned.to_excel("Data/test.xlsx", index=False)

# %% [markdown]
# Remarques :
#
# Nettoyage des données :
#
#    - Suppression des balises HTML dans les colonnes Points_forts, Expérience et Compétence.
#
#    - Élimination des doublons.
#
#    - Exclusion des profils dont les métiers ne relèvent pas du domaine IT (ex. RH, finance, marketing...).
#
# Enrichissement du dataset :
#
#    - Ajout de deux nouvelles colonnes : Contrat et Metier_regroupe.
#
#    - La colonne Contrat n’apporte pas beaucoup d’informations utiles, elle pourrait être ignorée par la suite.
#
#    - Pour la colonne Metier_regroupe, j’ai regroupé les métiers similaires (ex. Data Analyst, Data Engineer...) et attribué la valeur "Autre" aux profils ne correspondant à aucun regroupement précis.
#
#    - Environ la moitié des profils ont pu être classés dans un groupe spécifique.
